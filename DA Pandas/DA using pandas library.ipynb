# %% [markdown]
# # Loading data into pandas into different file format

# %%
import pandas as pd

# csv file format
# df = pd.read_csv('pokemon_data.csv')
# (comment here can use head or tail to specify the top or bottom of the data var that we want to print; 
#print(df.tail(3))

# xlsx file format
#df_xlsx = pd.read_excel('pokemon_data.xlsx')
#print(df_xlsx.head(3))

# Tab seperated txt file format
df = pd.read_csv('pokemon_data.txt', delimiter='\t')
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Reading Data in Pandas

# %%
### Read Headers
#print(df.columns)
df.columns

### Read each Column
# (specify the top 5 range) print(df['Name'][0:5])
# (print diff colm) print(df[['Name', 'Type 1', 'HP']])

### Read Each Row
#print(df.head(4))
# (use iloc fn to print specific row and print first 4 row and ranges 1 to 4) print(df.iloc[1:4])
#(iter) for index, row in df.iterrows():
 #   print(index, row['Name'])
#df.loc[df['Type 1'] == "Grass"]

### Read a specific location (R,C)
#print(df.iloc[2,1])
# Out:
# Venusaur

# %% [markdown]
# # Sorting/Describing Data

# %%
#df.describe()


#df.sort_values('Name', ascending = False)

#combine multiple col
df.sort_values(['Type 1', 'HP'], ascending=[1,0])
df
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1                  Bulbasaur     Grass  Poison   45      49       49
# 1      2                    Ivysaur     Grass  Poison   60      62       63
# 2      3                   Venusaur     Grass  Poison   80      82       83
# 3      3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4      4                 Charmander      Fire     NaN   39      52       43
# 5      5                 Charmeleon      Fire     NaN   58      64       58
# 6      6                  Charizard      Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 9      7                   Squirtle     Water     NaN   44      48       65
# 10     8                  Wartortle     Water     NaN   59      63       80
# ...

# %% [markdown]
# # Making changes to the data

# %%
# add a col to add all and find which pokemon data is best
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# drop a specific col, remove TOTAL from the dataset
#df = df.drop(columns=['Total'])

# add a col in different wayuse iloc fn,location all row then :, col specify which one 4:10 starts from 0;
#.sum fn add horizontally like axis =1, axix =0 adding vertically
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  count  Legendary   Total  HP  \
# 0  1              Bulbasaur  Grass  Poison      1      False   799.0  45
# 1  2                Ivysaur  Grass  Poison      1      False  1015.0  60
# 2  3               Venusaur  Grass  Poison      1      False  1315.0  80
# 3  3  VenusaurMega Venusaur  Grass  Poison      1      False  1595.0  80
# 4  4             Charmander   Fire     NaN      1      False   747.0  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %% [markdown]
# # Saving our Data/csv (Exporting into Desired Format)

# %%
#df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# # Filtering Data

# %%
#df.loc[(df['Type 1'] == 'Grass')]
#new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
#new_df.reset_index(drop=True, inplace=True)
#new_df

# Get type 1 grass or fire, regex expression means OR
import re
#df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]
# ignore the captial or lower case using FLAGS term, flags I ignore case
#df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
# catagory like want to find or start with "PI" or next set of letter from a~z, * mean more or zero on the statement
#df.loc[df['Name'].str.contains('pi[a~z]*', flags=re.I, regex=True)]
# find pi in the middle use ^ statement
df.loc[df['Name'].str.contains('^pi[a~z]*', flags=re.I, regex=True)]


# find only Mega from the file
#df.loc[df['Name'].str.contains('Mega')]
# Whne Reverse of this then just use the sign ~ squiggly line or tilde, NO MEGA on our data
#df.loc[~df['Name'].str.contains('Mega')]

#new_df.to_csv('filtered.csv')
# Out:
#        #                 Name    Type 1    Type 2  Legendary  Total   HP  \
# 20    16               Pidgey    Normal    Flying      False    446   40
# 21    17            Pidgeotto    Normal    Flying      False    627   63
# 22    18              Pidgeot    Normal    Flying      False    857   83
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False   1037   83
# 30    25              Pikachu  Electric       NaN      False    550   35
# 136  127               Pinsir       Bug       NaN      False    915   65
# 137  127    PinsirMega Pinsir       Bug    Flying      False   1095   65
# 186  172                Pichu  Electric       NaN      False    350   20
# 219  204               Pineco       Bug       NaN      False    565   50
# 239  221            Piloswine       Ice    Ground      False    850  100
# 438  393               Piplup     Water       NaN      False    588   53
# 558  499              Pignite      Fire  Fighting      False    781   90
# ...

# %% [markdown]
# # Conditional Changes, DF

# %%
# multiple condition can modify, gen, led are col here
df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']



# change our DataFrame based on condition we filter out, change the name Fire to Flamer or vice versa
#df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'


#  specify all the fire pokemon are legendary and true
#df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True

#df = pd.read_csv('modified.csv')

df
# Out:
#    #                   Name Type 1  Type 2 Legendary  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison    Test 2    591  45      49
# 1  2                Ivysaur  Grass  Poison    Test 2    750  60      62
# 2  3               Venusaur  Grass  Poison    Test 2    970  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison    Test 2   1170  80     100
# 4  4             Charmander   Fire     NaN    Test 2    553  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed Generation
# 0       49       65       65     45     Test 1
# 1       63       80       80     60     Test 1
# 2       83      100      100     80     Test 1
# 3      123      122      120     80     Test 1
# 4       43       60       50     65     Test 1

# %% [markdown]
# # Aggregate Statistics or Groupby fn

# %%
df = pd.read_csv('modified.csv')

# avg, can find which pokemon has highest Defense/HP/Attack/ so on, ascending wise
#df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)

#sum
#df.groupby(['Type 1']).sum().sort_values('Defense', ascending=False)

#count
#df.groupby(['Type 1']).count()

df['count'] = 1

# get the count col, also can multiple parameter like T1 or T2
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1    Type 2
# Bug       Electric     2
#           Fighting     2
#           Fire         2
#           Flying      14
#           Ghost        1
#           Grass        6
#           Ground       2
#           Poison      12
#           Rock         3
#           Steel        7
#           Water        1
# Dark      Dragon       3
#           Fighting     2
#           Fire         3
#           Flying       5
#           Ghost        2
#           Ice          2
#           Psychic      2
#           Steel        2
# Dragon    Electric     1
#           Fairy        1
#           Fire         1
#           Flying       6
#           Ground       5
#           Ice          3
#           Psychic      4
# Electric  Dragon       1
#           Fairy        1
#           Fire         1
#           Flying       5
#                       ..
# Rock      Fighting     1
#           Flying       4
#           Grass        2
#           Ground       6
#           Ice          2
# ...

# %% [markdown]
# # Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
    
    
    #print("chunk df")
   # print(df)


# pandas lib can read a chunk of the size 5 (or thousands rows) mean 5 rows pass at the same time, 
# for df mean5 rows of my total data size. 
#new_df = pd.DataFrame(columns=df.columns)

#for df in pd.read_csv('modified.csv', chunksize=5):
    #results = df.groupby(['Type 1']).count()
    
    #new_df = pd.concat([new_df, results])
# concate fn, take new df to chunks, pandas on results and stored into ur new_df
# Out:
# /home/jahid/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
