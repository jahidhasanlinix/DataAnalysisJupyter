# %%
import datetime
import hashlib

# %%
class Block:
    blockNo = 0
    data = None
    next = None
    hash = None
    nonce = 0
    previous_hash = 0x0
    timestamp = datetime.datetime.now()

    def __init__(self, data):
        self.data = data

    def hash(self):
        h = hashlib.sha256()
        h.update(
        str(self.nonce).encode('utf-8') +
        str(self.data).encode('utf-8') +
        str(self.previous_hash).encode('utf-8') +
        str(self.timestamp).encode('utf-8') +
        str(self.blockNo).encode('utf-8')
        )
        return h.hexdigest()

    def __str__(self):
        return "Block Hash: " + str(self.hash()) + "\nBlockNo: " + str(self.blockNo) + "\nBlock Data: " + str(self.data) + "\nHashes: " + str(self.nonce) + "\n--------------"

# %%
class Blockchain:

    diff = 20
    maxNonce = 2**32
    target = 2 ** (256-diff)

    block = Block("Genesis")
    dummy = head = block

    def add(self, block):

        block.previous_hash = self.block.hash()
        block.blockNo = self.block.blockNo + 1

        self.block.next = block
        self.block = self.block.next

    def mine(self, block):
        for n in range(self.maxNonce):
            if int(block.hash(), 16) <= self.target:
                self.add(block)
                print(block)
                break
            else:
                block.nonce += 1

blockchain = Blockchain()

# %%
for n in range(10):
    blockchain.mine(Block("Block " + str(n+1)))

while blockchain.head != None:
    print(blockchain.head)
    blockchain.head = blockchain.head.next
# Out:
# Block Hash: 34005662052e5bda001d0ecb3db49efb954afc88d03661dd2756caa28efba074
# BlockNo: 1
# Block Data: Block 1
# Hashes: 659426
# --------------
# Block Hash: abd84133d0cd7e01e0c6bb620c0cfdeaaecec480f126eb2fa420444228cadb0f
# BlockNo: 2
# Block Data: Block 2
# Hashes: 1155437
# --------------
# Block Hash: 485170b3aca0b301ac29cd52c508049afee472aa7f98e0e022cfe8d668165394
# BlockNo: 3
# Block Data: Block 3
# Hashes: 1346330
# --------------
# Block Hash: 0a29a33647c6014391ff9e2a2535ee4f788c41e7fd15dc55bc4d96ea890270b4
# BlockNo: 4
# Block Data: Block 4
# Hashes: 10250
# --------------
# Block Hash: 5db4ba193038f02352318352f3944c1bb6af17e8a2868009dfed67d7b43f08a8
# BlockNo: 5
# Block Data: Block 5
# Hashes: 663346
# --------------
# Block Hash: 080497760410ddb72ef498376bc3008bfb83def6fc2d06c04a51339ef8f6d928
# BlockNo: 6
# Block Data: Block 6
# Hashes: 752464
# --------------
# Block Hash: 4329544e56458dd7762540ef4605cba75e24f53351d51dc025345a6afe4cf022
# BlockNo: 7
# Block Data: Block 7
# Hashes: 117367
# --------------
# Block Hash: cf2cef9019a6d32f94871d5492e6522eae6184dc4fec621c6c03510c879230bb
# BlockNo: 8
# Block Data: Block 8
# Hashes: 620357
# --------------
# Block Hash: 549dc9f80b6ae620246201941f945a2f8f67dd13c43afb8778f3093fb0adaf58
# BlockNo: 9
# Block Data: Block 9
# Hashes: 965806
# --------------
# Block Hash: c270586c5e248c952ab8fb419380745881c72d5cdba19282877d79d0c1691138
# BlockNo: 10
# Block Data: Block 10
# Hashes: 812922
# --------------
# Block Hash: 8f27edaf9a21ced4e2a42ece7b44a8c6cf1f0dc9fb0e562b5bf5f2627fdb3c5d
# BlockNo: 0
# Block Data: Genesis
# Hashes: 0
# --------------
# Block Hash: 34005662052e5bda001d0ecb3db49efb954afc88d03661dd2756caa28efba074
# BlockNo: 1
# Block Data: Block 1
# Hashes: 659426
# --------------
# Block Hash: abd84133d0cd7e01e0c6bb620c0cfdeaaecec480f126eb2fa420444228cadb0f
# BlockNo: 2
# Block Data: Block 2
# Hashes: 1155437
# --------------
# Block Hash: 485170b3aca0b301ac29cd52c508049afee472aa7f98e0e022cfe8d668165394
# BlockNo: 3
# Block Data: Block 3
# Hashes: 1346330
# --------------
# Block Hash: 0a29a33647c6014391ff9e2a2535ee4f788c41e7fd15dc55bc4d96ea890270b4
# BlockNo: 4
# Block Data: Block 4
# Hashes: 10250
# --------------
# Block Hash: 5db4ba193038f02352318352f3944c1bb6af17e8a2868009dfed67d7b43f08a8
# BlockNo: 5
# Block Data: Block 5
# Hashes: 663346
# --------------
# Block Hash: 080497760410ddb72ef498376bc3008bfb83def6fc2d06c04a51339ef8f6d928
# BlockNo: 6
# Block Data: Block 6
# Hashes: 752464
# --------------
# Block Hash: 4329544e56458dd7762540ef4605cba75e24f53351d51dc025345a6afe4cf022
# BlockNo: 7
# Block Data: Block 7
# Hashes: 117367
# --------------
# Block Hash: cf2cef9019a6d32f94871d5492e6522eae6184dc4fec621c6c03510c879230bb
# BlockNo: 8
# Block Data: Block 8
# Hashes: 620357
# --------------
# Block Hash: 549dc9f80b6ae620246201941f945a2f8f67dd13c43afb8778f3093fb0adaf58
# BlockNo: 9
# Block Data: Block 9
# Hashes: 965806
# --------------
# Block Hash: c270586c5e248c952ab8fb419380745881c72d5cdba19282877d79d0c1691138
# BlockNo: 10
# Block Data: Block 10
# Hashes: 812922
# --------------
